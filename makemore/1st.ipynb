# %%
words = open("/home/the_programmer/programming/Neural_101/names.txt",'r').read().splitlines()
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %%
len(words)
# Out:
# 32033

# %%
# To know shortest and longest word size we can do

min(len(w) for w in words)
# Out:
# 2

# %%
max(len(w) for w in words)
# Out:
# 15

# %%
# to itrate over current and next word we do: 

for w in words[:1]:
    chs = ['<S>'] + list(w) + ['<E>']
    for ch1, ch2 in zip(chs,chs[1:]):
        print(ch1,ch2)
# Out:
# <S> e
# e m
# m m
# m a
# a <E>

# %%
# whats happening bcz of zip is :
print(w,w[1:])
print(w)
print(list(w))
# Out:
# emma mma
# emma
# ['e', 'm', 'm', 'a']
